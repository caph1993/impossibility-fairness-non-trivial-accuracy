# %% [markdown]
# # Algorithm 1 and Figures
#
# Requirements:
#
# ```
# pip3 install numpy scipy matplotlib SciencePlots
# ````

# %%
import matplotlib.pyplot as plt
plt.style.use('science') # pip3 install SciencePlots
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["figure.dpi"] = 200

from importlib import reload
import equal_opportunity

# %%
reload(equal_opportunity)
from equal_opportunity import (
    DataSource
)


D = DataSource.atRandom(100, seed=5)
# D.the_plot(r=0, constants=True)
# D.the_plot()

D_emp = D.empirical(1000, seed=5)
D.the_plot(D_emp, r=0)
D.the_plot(D_emp, r=1.5)


D_emp.the_plot(D, r=0)
D_emp.the_plot(D, r=1.5)

# %%
D = DataSource.atRandom(100, seed=0, bias=0.7)
D.plot_many_empiricals(100, 2500)
D.plot_many_empiricals(100, 500)
D.plot_many_empiricals(100, 100)

# %%
D = DataSource.atRandom(40, seed=3)
D_emp = D.empirical(1000, seed=3)
D.the_plot(D_emp, r=0.3, pareto_movements=False)
