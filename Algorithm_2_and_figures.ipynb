# %% [markdown]
# # Algorithm 1 and Figures
#
# Requirements:
#
# ```
# pip3 install numpy scipy matplotlib SciencePlots
# ````

# %%
from typing import List, Tuple, Sequence, Iterable
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science') # pip3 install SciencePlots
plt.rcParams["figure.figsize"] = (4, 2.5)
plt.rcParams["figure.dpi"] = 250
#plt.rcParams["font.size"] = 18

from cp93pytools.methodtools import cached_property

from importlib import reload
import equal_opportunity
#[*plt.rcParams.keys()]

# %%
reload(equal_opportunity)
from equal_opportunity import (
    DataSource
)

D = DataSource.atRandom(3, seed=22)
for i in [5, 12]:
    D.the_plot(r=0, constants=True, hull_border=True,
    n_random=1, extra_seed=i,
    pareto_movements=False,
    )

# %%
DataSource.atRandom(1000, seed=1, bias=-1.5).the_plot(
    r=0,
    constants=True,
    hull_border=False,
    n_random=0,
    pareto_movements=False,
)

# %%
#for seed in range(15):
DataSource.atRandom(100, seed=1, bias=1.5).the_plot(
    constants=True,
    hull_border=False,
    n_random=0,
    pareto_movements=False,
)
DataSource.atRandom(100, seed=1, bias=1.5).the_plot(
    r=0,
    constants=True,
    hull_border=False,
    n_random=0,
    pareto_movements=False,
)
